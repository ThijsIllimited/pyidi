# %%
import os
import sys

# Get the directory of the current file
current_dir = os.path.dirname(os.path.realpath('__file__'))

# Get the parent directory
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the system path
sys.path.insert(0, parent_dir)
import numpy as np              # Python's standard numerical library
import matplotlib.pyplot as plt # Python's scientific visualization library
import pyidi                    # Python HSC data analysis library
import pickle as pk
from pixel_setter2 import PixelSetter#, play_video, detect_peaks
from pixel_setter import play_video
from scipy.ndimage import uniform_filter
import importlib
from EMA_functions import *
from Feature_selecter import *
import matplotlib.animation as animation
from pyidi import ROISelect
from matplotlib.path import Path
import time
import glob
import itertools
root_drive_sim = os.path.normpath('G:/.shortcut-targets-by-id/1k1B8zPb3T8H7y6x0irFZnzzmfQPHMRPx/Illimited Lab Projects/Research Projects/Spiders/Simulations')

# Find all files ending with .cih in the folder
files = glob.glob('D:/thijsmas/HSC/**/*.cihx', recursive=True)

reference_image = (0, 150)
roi_size = (9,9)
bit_depth = 16
n_tracking_points = 3000

line_styles = ['-', '--', '-.', ':']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# Create a cycle iterator for line styles and colors
line_style_cycle = itertools.cycle(line_styles)
color_cycle = itertools.cycle(colors)

dic_type = '2D'
processors = 1
for file_i, file in enumerate(files):
    print(f"processing {file_i} out of {len(files)-1}")

    file_name = file.split('\\')[-1]
    file_name_base = file_name.split('.')[0]
    file_root = file.split(file_name)[0]
    save_file = os.path.join(file_root, f"{file_name_base}_analyzed.txt")

    if os.path.exists(save_file):
        continue
    
    file_name_points = os.path.join(file_root, f"{file_name_base}_points.npz")
    data = np.load(file_name_points)
    reference_image = data['referece_image']
    roi_size = data['roi_size']
    dic_type = data['type']
    points = data['points']
    n_tracking_points = points.shape[0]
    file_name_roi = os.path.join(file_root, f"{file_name_base}_ROI.npy")
    ROI = np.load(file_name_roi)
    path = Path(ROI.T)
    

    EMA_structure = EMA_Structure(file_name)
    video = EMA_structure.open_video(add_extension=False)
    mean_image = video.mraw[reference_image[0]:reference_image[1]].mean(axis=0)
    if dic_type == '2D':
        video.set_method('lk')
    elif dic_type == '1D':
        video.set_method('lk_1D')
    else:
        raise ValueError('Unknown tracking type')
    video.method.configure(roi_size = roi_size, reference_image = mean_image,  resume_analysis=False)
    video.set_points(points)
    video.get_displacements(processes = processors)

    with open(os.path.join(file_root, f"{file_name_base}_analyzed.txt"), 'w') as file:
        file.write(f"File: {file_name}\n")
        file.write(f"Reference Image: {reference_image}\n")
        file.write(f"ROI Size: {roi_size}\n")
        file.write(f"Tracking Type: {dic_type}\n")
        file.write(f"Number of Tracking Points: {n_tracking_points}\n")
        

    # fig, ax = plt.subplots(figsize=(15, 20))
    # ax.imshow(mean_image, cmap='gray')
    # ax.set_title(file_name_base + ' ' + str(n_tracking_points) + ' points')
    # ax.plot(ROI[1], ROI[0], label = 'ROI', linestyle='-', color='r')
    # points_plot = ax.scatter(points[:,1], points[:,0], marker='o',s=10)
    # ax.legend()
    # plt.show()
# Out:
# processing 0 out of 173
# processing 1 out of 173
# processing 2 out of 173
# processing 3 out of 173
# processing 4 out of 173
# processing 5 out of 173
# processing 6 out of 173
# processing 7 out of 173
# processing 8 out of 173
# processing 9 out of 173
# processing 10 out of 173
# processing 11 out of 173
# processing 12 out of 173
# processing 13 out of 173
# processing 14 out of 173
# processing 15 out of 173
# processing 16 out of 173
# processing 17 out of 173
# processing 18 out of 173
# processing 19 out of 173
# processing 20 out of 173
# processing 21 out of 173
# processing 22 out of 173
# processing 23 out of 173
# processing 24 out of 173
# processing 25 out of 173
# processing 26 out of 173
# processing 27 out of 173
# processing 28 out of 173
# processing 29 out of 173
# processing 30 out of 173
# processing 31 out of 173
# processing 32 out of 173
# processing 33 out of 173
# processing 34 out of 173
# processing 35 out of 173
# processing 36 out of 173
# processing 37 out of 173
# processing 38 out of 173
# processing 39 out of 173
# processing 40 out of 173
# processing 41 out of 173
# processing 42 out of 173
# processing 43 out of 173
# processing 44 out of 173
# processing 45 out of 173
# processing 46 out of 173
# processing 47 out of 173
# processing 48 out of 173
# processing 49 out of 173
# processing 50 out of 173
# processing 51 out of 173
# processing 52 out of 173
# processing 53 out of 173
# processing 54 out of 173
# processing 55 out of 173
# processing 56 out of 173
# processing 57 out of 173
# processing 58 out of 173
# processing 59 out of 173
# processing 60 out of 173
# processing 61 out of 173
# processing 62 out of 173
# processing 63 out of 173
# processing 64 out of 173
# processing 65 out of 173
# processing 66 out of 173
# processing 67 out of 173
# processing 68 out of 173
# processing 69 out of 173
# processing 70 out of 173
# processing 71 out of 173
# processing 72 out of 173
# processing 73 out of 173
# processing 74 out of 173
# processing 75 out of 173
# processing 76 out of 173
# processing 77 out of 173
# processing 78 out of 173
# processing 79 out of 173
# processing 80 out of 173
# processing 81 out of 173
# processing 82 out of 173
# processing 83 out of 173
# processing 84 out of 173
# processing 85 out of 173
# processing 86 out of 173
# processing 87 out of 173
# processing 88 out of 173
# processing 89 out of 173
# processing 90 out of 173
# processing 91 out of 173
# processing 92 out of 173
# processing 93 out of 173
# processing 94 out of 173
# processing 95 out of 173
# processing 96 out of 173
# processing 97 out of 173
# processing 98 out of 173
# processing 99 out of 173
# processing 100 out of 173
# processing 101 out of 173
# processing 102 out of 173
# processing 103 out of 173
# processing 104 out of 173
# processing 105 out of 173
# processing 106 out of 173
# processing 107 out of 173
# processing 108 out of 173
# processing 109 out of 173
# processing 110 out of 173
# processing 111 out of 173
# processing 112 out of 173
# processing 113 out of 173
# processing 114 out of 173
# processing 115 out of 173
# processing 116 out of 173
# processing 117 out of 173
# processing 118 out of 173
# processing 119 out of 173
# processing 120 out of 173
# processing 121 out of 173
# processing 122 out of 173
# processing 123 out of 173
# processing 124 out of 173
# processing 125 out of 173
# processing 126 out of 173
# processing 127 out of 173
# processing 128 out of 173
# processing 129 out of 173
# processing 130 out of 173
# processing 131 out of 173
# processing 132 out of 173
# processing 133 out of 173
# processing 134 out of 173
# processing 135 out of 173
# processing 136 out of 173
# processing 137 out of 173
# processing 138 out of 173
# processing 139 out of 173
# processing 140 out of 173
# processing 141 out of 173
# processing 142 out of 173
# processing 143 out of 173
# processing 144 out of 173
# processing 145 out of 173
# processing 146 out of 173
# processing 147 out of 173
# processing 148 out of 173
# processing 149 out of 173
# processing 150 out of 173
# processing 151 out of 173
# processing 152 out of 173
# processing 153 out of 173
# processing 154 out of 173
# processing 155 out of 173
# processing 156 out of 173
# processing 157 out of 173
# processing 158 out of 173
# processing 159 out of 173
# processing 160 out of 173
# processing 161 out of 173
# processing 162 out of 173
# processing 163 out of 173
# processing 164 out of 173
# processing 165 out of 173
# processing 166 out of 173
# processing 167 out of 173
# processing 168 out of 173
# processing 169 out of 173
# processing 170 out of 173
# D:/thijsmas/HSC\ecc2\web1\rev2\Full_web_ecc2_new2_Floc19_v0_S01\Full_web_ecc2_new2_Floc19_v0_S01.cihx
# --- Starting new analysis ---
#
# Interpolating the reference image...
# ...done in 0.66 s
# VBox()
# C:\Users\thijsmas\Documents\GitHub\pyidi\pyidi\methods\_lucas_kanade.py:330: UserWarning: Reached image edge. The displacement optimization algorithm may not converge, or selected points might be too close to image border. Please check analysis settings.
#   warnings.warn('Reached image edge. The displacement optimization ' +
# C:\Users\thijsmas\Documents\GitHub\pyidi\pyidi\methods\_lucas_kanade.py:753: RuntimeWarning: divide by zero encountered in scalar divide
#   A_inv = 1/(GxGy**2 - Gx2*Gy2) * np.array([[GxGy, -Gx2], [-Gy2, GxGy]])
# C:\Users\thijsmas\Documents\GitHub\pyidi\pyidi\methods\_lucas_kanade.py:753: RuntimeWarning: invalid value encountered in multiply
#   A_inv = 1/(GxGy**2 - Gx2*Gy2) * np.array([[GxGy, -Gx2], [-Gy2, GxGy]])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 81
#      79 video.method.configure(roi_size = roi_size, reference_image = mean_image,  resume_analysis=False)
#      80 video.set_points(points)
# ---> 81 video.get_displacements(processes = processors)
#      83 with open(os.path.join(file_root, f"{file_name_base}_analyzed.txt"), 'w') as file:
#      84     file.write(f"File: {file_name}\n")
#
# File ~\Documents\GitHub\pyidi\pyidi\pyidi.py:173, in pyIDI.get_displacements(self, autosave, **kwargs)
#     164 """
#     165 Calculate the displacements based on chosen method.
#     166
#    (...)
#     170 ---
#     171 """
#     172 if hasattr(self, 'method'):
# --> 173     self.method.calculate_displacements(self, **kwargs)
#     174     self.displacements = self.method.displacements
#     176     # auto-save and clearing temp files
#
# File ~\Documents\GitHub\pyidi\pyidi\methods\_lucas_kanade.py:226, in LucasKanade.calculate_displacements(self, video, **kwargs)
#     223     yslice, xslice = self._padded_slice(point+d_init, self.roi_size, self.image_size, 1)
#     224     G = video.reader.get_frame(i)[yslice, xslice]
# --> 226     displacements = self.optimize_translations(
#     227         G=G,
#     228         F_spline=self.interpolation_splines[p],
#     229         maxiter=self.max_nfev,
#     230         tol=self.tol,
#     231         d_subpixel_init = -d_res
#     232         )
#     234     self.displacements[p, ii, :] = displacements + d_init
#     236 # temp
#
# File ~\Documents\GitHub\pyidi\pyidi\methods\_lucas_kanade.py:291, in LucasKanade.optimize_translations(self, G, F_spline, maxiter, tol, d_subpixel_init)
#     288 y_f += delta[0]
#     289 x_f += delta[1]
# --> 291 F = F_spline(y_f, x_f)
#     292 delta, error = compute_delta_numba(F, G_float_clipped, Gx, Gy, A_inv)
#     294 displacement += delta
#
# File c:\Users\thijsmas\AppData\Local\anaconda3\Lib\site-packages\scipy\interpolate\_fitpack2.py:1029, in _BivariateSplineBase.__call__(self, x, y, dx, dy, grid)
#    1026     return np.zeros((x.size, y.size), dtype=self.tck[2].dtype)
#    1028 if (x.size >= 2) and (not np.all(np.diff(x) >= 0.0)):
# -> 1029     raise ValueError("x must be strictly increasing when `grid` is True")
#    1030 if (y.size >= 2) and (not np.all(np.diff(y) >= 0.0)):
#    1031     raise ValueError("y must be strictly increasing when `grid` is True")
#
# ValueError: x must be strictly increasing when `grid` is True
